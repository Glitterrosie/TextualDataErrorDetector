# %%
import pandas as pd
data = pd.read_csv('../datasets/weather_subset1_group1_w_errors.csv')
labels_old = pd.read_csv('../datasets/weather_subset1_group1_w_errors_error_mappings_old.csv')
labels_new = pd.read_csv('../datasets/weather_subset1_group1_w_errors_error_mappings.csv')

for column in data.columns:
    for row in data.index:
        if labels_old[column][row] == 0 and labels_new[column][row] == 3:
            print(data[column][row])
# Out:
# 10.B
# 74.C
# 11.Z
# q.l
# ls.4
# B.8
# 8.b
# G.q
# z.8
# -l.1
# C.8
# Z.l
# l.C
# G.4
# 73.I
# S.C
# I.1
# B.4
# b.Z
# -D.b
# I.o
# I.S
# o.b
# 7.q
# s.C
# S.4
# S.8
# S.8
# z.7
# o.4
# C.S
# 0.B
# q.0
# Io.8
# s.0
# g.q
# o.q
# 8.o
# I.5
# C.4
# B.B
# l.4
# -l.s
# -8.Z
# Z.1
# S.4
# 8.s
# IS.4
# 10 .9
# lI.2
# g.S
# S.8
# -9.z
# -O.I
# 9.s
# B.S
# Z.z
# b.l
# C.0
# ZS.2
# lo.4
# B.z
# 0.I
# B.4
# S.S
# -I.1
# I.1
# Z.g
# 13. 6
# 74.D
# 18.b
# 8.S
# B.G
# -D.8
# b.C
# 8.C
# C.q
# 0.C
# 18.o
# lo.5
# lS.9
# 13 .8
# IS.2
# S.B
# 1.z
# z.l
# b.4
# 11.G
# 18.S
# 17.g
# -o.0
# 1.Z
# 72.b
# 1.O
# 4.B
# z.7
# -D.B
# G.z
# 70.O
# 74.G
# 73.Z
# 74.z
# 73.O
# Io.2
# 70.b
# l.q
# -l.o
# 1.z
# 19.z
# 1.B
# Z.B
# b.0
# 8.l
# q.g
# 18.g
# ls.8
# g.8
# z.q
# 0.B
# z.4
# 0.g
# I.0
# -o.C
# S.S
# C.4
# 17.1,
# q.S
# 17 .1
# q.l
# s.4
# z.5
# B.7
# b.b
# -9.B
# I.D
# Z.b
# D.q
# 9.s
# z.D
# 7.S
# z.z
# 1.g
# 73.S
# 11.b
# 11.O
# 77.S
# g.C
# 0.Z
# b.0
# S.3
# D.8
# B.z
# S.S
# IO.4
# 11.o
# G.B
# ...
