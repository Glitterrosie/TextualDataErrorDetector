# %%
import pandas as pd

# data = pd.read_csv('../datasets/imdb_subset1_group1_w_errors.csv')
# data = pd.read_csv('../datasets/weather_subset1_group1_w_errors.csv')
data = pd.read_csv('../datasets/medical_subset1_group1_w_errors.csv')

# data = pd.read_csv('../../TabularRedundancyPolluter/datasets/imdb_subset2_group2.csv')
# data = pd.read_csv('../../TabularRedundancyPolluter/datasets/weather_subset2_group2.csv')
# data = pd.read_csv('../../TabularRedundancyPolluter/datasets/medical_subset2_group2.csv')

uniques = {}
for column in data.columns:
    unique_values = data[column].unique()
    uniques[column] = unique_values

max_unique = max(len(values) for values in uniques.values())
unique_frame = pd.DataFrame(columns=data.columns, index=range(max_unique))
for column, values in uniques.items():
    unique_frame[column] = pd.Series(values)

display(unique_frame)
# Out:
#       encounter_id patient_nbr             race   gender  age weight  \
# 0          2278392     82z2151        Caucasian   Female    5     80
# 1           149190    55629189  AfricanAmerican     Male   17     S9
# 2            64410    86047875            Other  Ferna1e   23     s9
# 3           500364    82442376        6auca8ian     Ma1e   33     Bo
# 4            16680    42519267        6aocasian  Female,   40     S8
# ...            ...         ...              ...      ...  ...    ...
# 20349     71715132         NaN              NaN      NaN  NaN    NaN
# 20350     71726868         NaN              NaN      NaN  NaN    NaN
# 20351     71731212         NaN              NaN      NaN  NaN    NaN
# 20352     71740284         NaN              NaN      NaN  NaN    NaN
# 20353     71757270         NaN              NaN      NaN  NaN    NaN
#
#       admission_type_id discharge_disposition_id admission_source_id  \
# 0                    25                        6                   I
# 1                     1                        1                   7
# 2                     l                        l                   2
# 3                     3                        2                   4
# 4                     2                        3                   1
# ...                 ...                      ...                 ...
# 20349               NaN                      NaN                 NaN
# 20350               NaN                      NaN                 NaN
# 20351               NaN                      NaN                 NaN
# 20352               NaN                      NaN                 NaN
# 20353               NaN                      NaN                 NaN
#
#       time_in_hospital  ... glipizide-metformin glimepiride-pioglitazone  \
# 0                    1  ...                  No                       No
# 1                    3  ...                  Nu                       NO
# 2                    2  ...                  N0                       N0
# 3                    4  ...                  NO                       Nu
# 4                    5  ...                 No-                      No,
# ...                ...  ...                 ...                      ...
# 20349              NaN  ...                 NaN                      NaN
# 20350              NaN  ...                 NaN                      NaN
# 20351              NaN  ...                 NaN                      NaN
# 20352              NaN  ...                 NaN                      NaN
# 20353              NaN  ...                 NaN                      NaN
#
#       metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# 0                          No                     No     No          No
# 1                          Nu                     NO     Ch         Yes
# 2                          N0                     Nu    Yes          Ch
# 3                          NO                     N0    Gli         Ye8
# 4                         No,                    No,     NO          Nu
# ...                       ...                    ...    ...         ...
# 20349                     NaN                    NaN    NaN         NaN
# 20350                     NaN                    NaN    NaN         NaN
# 20351                     NaN                    NaN    NaN         NaN
# 20352                     NaN                    NaN    NaN         NaN
# 20353                     NaN                    NaN    NaN         NaN
#
#       readmitted admission_type_desc admission_source_desc  \
# 0             NO       Not Available    Physician Referral
# 1            >30           Emergency        Emergency Room
# 2             No           Emerbency        Emergency Rome
# 3            >8O              Urgent       Clinic Referral
# 4            <30            Elective        Emerrgency oom
# ...          ...                 ...                   ...
# 20349        NaN                 NaN                   NaN
# 20350        NaN                 NaN                   NaN
# 20351        NaN                 NaN                   NaN
# 20352        NaN                 NaN                   NaN
# 20353        NaN                 NaN                   NaN
#
#       discharge_disposition_desc
# 0                     Not Mapped
# 1            Discharged to home]
# 2             Discharged fo homw
# 3             Discharged te hope
# 4             Discharged to home
# ...                          ...
# 20349                        NaN
# 20350                        NaN
# 20351                        NaN
# 20352                        NaN
# 20353                        NaN
#
# [20354 rows x 53 columns]

# %%
# original data
original_data = pd.read_csv('../datasets/imdb_subset2_group2.csv')
print("Min:", original_data[['cast_id']][original_data.cast_id == original_data.cast_id.min()])
print("Max:", original_data[['cast_id']][original_data.cast_id == original_data.cast_id.max()])
#print("Min: ", original_data["cast_id"].min, " Max: ", original_data["cast_id"].min)
# Out:
# Min:          cast_id
# 164719  25231029
# Max:          cast_id
# 199999  36044858
