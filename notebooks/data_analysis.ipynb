# %% [markdown]
# # Weather Dataset
# ### MinTemp > MaxTemp Transposition

# %%
import pandas as pd

data = pd.read_csv('../datasets/weather_subset1_group1_w_errors.csv')

# %%
def is_numeric(value: str):
    try:
        float(value)
        return True
    except ValueError:
        return False

both_numeric = data[data['MinTemp'].apply(is_numeric) & data['MaxTemp'].apply(is_numeric)]
filtered = both_numeric[both_numeric['MinTemp'].astype(float) > both_numeric['MaxTemp'].astype(float)]
display(filtered)
# Out:
#              Date   Location MinTemp MaxTemp Rainfall Evaporation Sunshine  \
# 20     2008-12-21    Alburyg    29.3    11.5      0.0     15.3712    14.03
# 43     2009-01-13    Alburyg    37.7    17.2      0.0     15.3712    14.03
# 59     2009-01-29    Alburyg    41.5    21.8      0.0     15.3712    14.03
# 87     20o9-02-2G    Alburyg    30.5    20.7      0.0     15.3712    14.03
# 116    2009-03-27    Alburyg    27.6    10.1      0.0     15.3712    14.03
# ...           ...        ...     ...     ...      ...         ...      ...
# 28928  2014-01-25   Richmond    26.7    16.6      2.8     15.3712    14.03
# 28934  2014-01-31   Richmond    38.1    13.6      0.0         7.4    14.03
# 28979  2014-03-17   BichmOnd  33.229    27.4  124.803        11.4    14.03
# 29064  2014-06-10   Bichmund  33.229    15.4      3.4     15.3712    14.03
# 29074  2014-06-20  Richmmond    21.9     7.1      0.0     15.3712    14.03
#
#       WindGustDir WindGustSpeed WindDir9am  ... Humidity9am Humidity3pm  \
# 20              S          24.0         SE  ...        28.0        56.0
# 43            NNW          35.0         SE  ...        19.0        51.0
# 59             SW          24.0        ESE  ...        13.0        38.0
# 87            ESE          26.0        ESE  ...        19.0        43.0
# 116           WNW          43.0          N  ...        30.0        63.0
# ...           ...           ...        ...  ...         ...         ...
# 28928          SE          44.0          N  ...        80.0        43.0
# 28934         ENE          28.0          N  ...        69.0        23.0
# 28979           W          28.0          N  ...       87.62        32.0
# 29064           W        29.993        SSE  ...       87.62       74.18
# 29074          SE          33.0          N  ...        97.0        59.0
#
#       Pressure9am Pressure3pm Cloud9am Cloud3pm  Temp9am  Temp3pm RainToday  \
# 20         1019.3      1014.8    6.994    5.Co4     19.1     27.3        No
# 43         1010.9      1015.7    6.994    5.604     24.3     35.7        No
# 59         1015.7      1011.8    6.994    5.604     29.0     40.1        No
# 87         1017.8      1015.0    6.994    5.G84     32.7     15.0        No
# 116        1020.7      1023.0    5.604    6.994     16.5     26.8        No
# ...           ...         ...      ...      ...      ...      ...       ...
# 28928      1011.9      1014.3    6.994    5.604     Zl.6     24.0       Yes
# 28934      1015.1      1010.4    6.994    5.604     21.1     35.0        No
# 28979    1014.955      1014.8    6.994    5.604  26.4356     26.1        No
# 29064      1027.6      1031.2      8.0      8.0  26.4356  8Z.5473       Yes
# 29074      1019.7      1015.7    6.994      1.0      9.9     19.6        No
#
#       RainTomorrow
# 20              No
# 43              No
# 59              No
# 87              No
# 116             No
# ...            ...
# 28928           No
# 28934           No
# 28979           No
# 29064           No
# 29074           N0
#
# [1351 rows x 23 columns]

# %% [markdown]
# ### Rainfall Evaporation Transposition

# %%
both_numeric = data[data['Rainfall'].apply(is_numeric) & data['Evaporation'].apply(is_numeric)]
display(both_numeric)
rainfall_contains_153712 = both_numeric[both_numeric['Rainfall'].astype(float) == 15.3712]
# display(rainfall_contains_153712)
# Out:
#              Date   Location MinTemp MaxTemp Rainfall Evaporation Sunshine  \
# 0      2008-12-01    Alburyg    IB.4    22.9      0.6     15.3712    14.03
# 1      2008-12-02    Alburyg     7.4    zS.1    14.03     15.3712      0.0
# 2      2008-12-03    Alburyg    12.9    25.7      0.0     15.3712    14.03
# 3      2008-12-04    Alburyg     9.2    28.0    14.03     15.3712      0.0
# 4      2008-12-05    Alburyg    l7.8    32.3      1.0       14.03  15.3712
# ...           ...        ...     ...     ...      ...         ...      ...
# 29087  2014-07-03    Ricmond    -1.4    18.4      0.0     15.3712    14.03
# 29088  2014-07-04   Eichmond    -3.3    zZ.2      0.0     15.3712    14.03
# 29089  2014-07-05  Richmoond     0.0    18.5      0.0     15.3712    14.03
# 29090  2014-07-06  Rrichmond     1.4    17.8      0.0     15.3712    14.03
# 29091  2014-07-07   Richmond    -1.2    18.9    14.03     15.3712      0.0
#
#       WindGustDir WindGustSpeed WindDir9am  ... Humidity9am Humidity3pm  \
# 0               W          44.0          W  ...        22.0        71.0
# 1             WNW          22.0        NNW  ...        25.0        44.0
# 2             WSW          46.0          W  ...        30.0        38.0
# 3              NE          24.0         SE  ...        16.0        45.0
# 4               W          41.0        ENE  ...        33.0        82.0
# ...           ...           ...        ...  ...         ...         ...
# 29087         ESE          11.0          E  ...        98.0        37.0
# 29088           W          30.0          N  ...        90.0        24.0
# 29089         WNW          48.0         NE  ...        74.0        39.0
# 29090           W          39.0        NNE  ...        66.0        39.0
# 29091           W          33.0          N  ...        42.0        82.0
#
#       Pressure9am Pressure3pm Cloud9am Cloud3pm Temp9am Temp3pm RainToday  \
# 0          1007.7      1007.1      8.0    5.604    lC.9    21.8        No
# 1          1007.8      1010.6    6.994    5.604    17.2    24.3        No
# 2          1007.6      1008.7    6.994      2.0    21.0    23.2        No
# 3          1017.6      1012.8    C.g94    5.604    I3.1    26.5        No
# 4          1010.8      1006.0      7.0      8.0    17.8    29.7        No
# ...           ...         ...      ...      ...     ...     ...       ...
# 29087      1027.9      1023.3      5.0    5.604     3.8    17.7        No
# 29088      1021.7      1016.2    6.994    5.604     3.7    21.7        No
# 29089      1016.6      1013.2    6.994    5.604     8.2    16.9        No
# 29090      1014.2      1011.3    6.994      5.0    11.1    16.4        No
# 29091      1015.1      1012.4    6.994      1.0     5.3    I1.4        No
#
#       RainTomorrow
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 29087           No
# 29088           No
# 29089           No
# 29090           No
# 29091           No
#
# [26275 rows x 23 columns]

# %% [markdown]
# ### Evaporation Sunshine Transposition

# %%
both_numeric = data[data['Sunshine'].apply(is_numeric) & data['Evaporation'].apply(is_numeric)]
switched_data = both_numeric[
    (both_numeric['Sunshine'].astype(float) == 15.3712) | (both_numeric['Evaporation'].astype(float) == 14.03)
]
display(switched_data)
# Out:
#              Date   Location MinTemp MaxTemp Rainfall Evaporation Sunshine  \
# 4      2008-12-05    Alburyg    l7.8    32.3      1.0       14.03  15.3712
# 21     2008-12-22    Alburyg    17.1    33.0      0.0       14.03  15.3712
# 58     2009-01-28    Alburyg    20.4    40.7      0.0       14.03  15.3712
# 143    2009-04-23    Alburyg     6.0    22.9      0.0       14.03  15.3712
# 183    2009-06-02    Alburyg     8.4    13.4      1.4       14.03  15.3712
# ...           ...        ...     ...     ...      ...         ...      ...
# 28936  2014-9z-02  Richmond]    19.2    33.0      0.0       14.03  15.3712
# 28953  2014-02-19   Richmond    19.9    26.4      0.0       14.03      2.8
# 28992  2014-03-30   Richmond    lB.1    27.4      1.4       14.03  15.3712
# 29027  2014-05-04  Rgichmond    12.1    19.8      0.2       14.03  15.3712
# 29053  2014-o5-80   BichmOnd    1l.0    Ig.9      8.9       14.03  15.3712
#
#       WindGustDir WindGustSpeed WindDir9am  ... Humidity9am Humidity3pm  \
# 4               W          41.0        ENE  ...        33.0        82.0
# 21              N          17.0         NE  ...        28.0        38.0
# 58              N          37.0          E  ...        15.0        45.0
# 143            NE          33.0          N  ...        34.0        68.0
# 183            SE          13.0          N  ...        75.0        78.0
# ...           ...           ...        ...  ...         ...         ...
# 28936         ENE          35.0          E  ...        72.0        37.0
# 28953          SW          24.0        NNE  ...        97.0        97.0
# 28992         ESE          41.0          N  ...       100.0        50.0
# 29027         WSW          50.0        WNW  ...        48.0        38.0
# 29053         55W          11.8          N  ...        7I.D        G1.D
#
#       Pressure9am Pressure3pm Cloud9am Cloud3pm Temp9am Temp3pm RainToday  \
# 4          1010.8      1006.0      7.0      8.0    17.8    29.7        No
# 21         1013.6      1008.1    6.994      1.0    24.5    31.6        No
# 58         1011.6      1014.9    6.994    5.604    28.2    39.2        No
# 143        1021.3      1015.7    6.994    5.604    1Z.g    22.6        No
# 183        1029.3      1026.2      8.0      8.0    10.6    13.4       Yes
# ...           ...         ...      ...      ...     ...     ...       ...
# 28936      1015.4      1012.4    6.994    5.604    23.1    32.4        No
# 28953      1004.6      1002.1    6.994    5.604    22.6    22.3        No
# 28992      1020.3      1018.4    6.994    5.604    19.8    Z1.1       Yes
# 29027      1002.5      1005.2      1.0      1.0    16.7    18.1        No
# 29053      1O27.Z      7O24.6      S.9      s.O    1S.B    11.g        NO
#
#       RainTomorrow
# 4               No
# 21              No
# 58              No
# 143             No
# 183            Yes
# ...            ...
# 28936           No
# 28953          Yes
# 28992          Yes
# 29027           No
# 29053           N0
#
# [908 rows x 23 columns]

# %% [markdown]
# ## IMDB

# %%
import pandas as pd
data = pd.read_csv('../datasets/imdb_subset1_group1_w_errors.csv')

# %% [markdown]
# ### Testing the tokenization and spell checking

# %%
import re
from spellchecker import SpellChecker

test_value_cast_note = data['cast_note'][0]
print(test_value_cast_note)

spell = SpellChecker()

REGEX = r'\W'
tokens = re.split(REGEX, str(test_value_cast_note))
print(tokens)

for token in tokens:
    if not token:
        continue
    if not spell.known([token]):
        print(f"Misspelled token: {token}")
        suggestions = spell.candidates(token)
        print(f"Suggestions: {suggestions}")
    else:
        print(f"Correctly spelled token: {token}")
# Out:
# (localition meneger)
# ['', 'localition', 'meneger', '']
# Misspelled token: localition
# Suggestions: {'location', 'localities', 'localization', 'coalition'}
# Misspelled token: meneger
# Suggestions: {'reneger'}

# %% [markdown]
# # IMDB

# %%
data = pd.read_csv('../datasets/imdb_subset1_group1_w_errors.csv')
original_data = pd.read_csv('../datasets/imdb_subset2_group2.csv')
both_numeric = data[data['cast_movie_id'].apply(is_numeric) & data['person_movie_id'].apply(is_numeric)]
switched_data = both_numeric[
    both_numeric['cast_movie_id'].astype(float) != both_numeric['person_movie_id'].astype(float)
]
display(switched_data)

original_data = data[data['cast_movie_id'].apply(is_numeric) & data['person_movie_id'].apply(is_numeric)]
# Out:
#          cast_id cast_person_id cast_movie_id cast_person_role_id  \
# 10      35651134        3559741       2224908            999999.0
# 105     35652663        1627774       7363320            999999.0
# 145     35653197        3217594       7648090            999999.0
# 283     35655806        4005958       1955328            999999.0
# 444     35656768        4006055       2500736            999999.0
# ...          ...            ...           ...                 ...
# 199545   1779439       31764787       1916800            999999.0
# 199564   1779439       31764787       1016300            999999.0
# 199807   3581894       31764835       1938944            999999.0
# 199818   3581894       31764835       1988044            999999.0
# 199988   3581894       31764835       1938944            999999.0
#
#                             cast_note cast_nr_order cast_role_id person_id  \
# 10                (locationn managrr)      999999.0           10   8035046
# 105              (cretive concultant)      999999.0           10   9162829
# 145                      (trasnlatro)      999999.0           10   3327189
# 283            (prodution accountent)      999999.0           10   7778487
# 444             (printed producction)      999999.0           10  14660604
# ...                               ...           ...          ...       ...
# 199545  (looping voises) (uncredited)      99999g.O           10   1371187
# 199564  (lookping voicec) (uncredted)      999999.0           10   1371206
# 199807    (assestant: Mr.. Radcliffe)      999999.0           10    992337
# 199818     (assistant: Mr. Radcliffe)      999999.0           10    992348
# 199988     (ssistant: Mr. Radfcliffe)      999999.0           10    600447
#
#        person_movie_id person_info_type_id  ... imdb_index kind_id  \
# 10             2224000                   4  ...       VIII       1
# 105            1363328                   1  ...       VIII       7
# 145            1648000                   2  ...       VIII       1
# 283            1058328                   4  ...          I       1
# 444            2590136                  16  ...       VIII       1
# ...                ...                 ...  ...        ...     ...
# 199545         1916080                 107  ...       VIII       1
# 199564         1916800                 107  ...       VIII       1
# 199807         7988944                  17  ...       VIII       1
# 199818         1938944                  17  ...       VIII       I
# 199988         1985944                  15  ...       VIII       1
#
#        production_year phonetic_code episode_of_id season_nr episode_nr  \
# 10              2001.0         P6231     3844106.0      94.0     5070.0
# 105             2012.0        P25535     1363295.0       3.0        7.0
# 145             1998.0         D6555     3844106.0      94.0     5070.0
# 283             2009.0            H5     3844106.0      94.0     5070.0
# 444             1984.0         W4312     8844I06.0      94.0     5070.0
# ...                ...           ...           ...       ...        ...
# 199545          2003.0         G2321     3844106.0      94.0     5070.0
# 199564          2003.0        Gg2321     3844106.0      94.0     5070.0
# 199807          2001.0        H613w6     3844106.0      94.0     5070.0
# 199818          2001.0         H6136     3844106.0      94.0     5070.0
# 199988          2001.0         H61w6     3844106.0      94.0     5070.0
#
#        series_years                            md5sum           name
# 10            201q6  d9f609153b42fb962aafcf2bad20e392  Not Available
# 105            2016  20b144c7c2b40151ac799a0a0be7f280  Not Available
# 145            201t  678c3ad1f92a6c17221ca97f962991f8  Not Available
# 283             201  82bb89b9caf69be4895e527bf462cfe7  Not Available
# 444            2016  1596ec89decab19c9117da64009a14a0  Not Available
# ...             ...                               ...            ...
# 199545         2016  09e7d9572fa402da1173683a973ff073  Not Available
# 199564        22016  09e7d9572fa402da1173683a973ff073  Not Available
# 199807         2016  6418d35cb9e4625ea13674b15ddf200b  Not Available
# 199818         2016  6418d35cb9e4625ea13674b15ddf200b  Not Available
# 199988         2016  6418d35cb9e4625ea13674b15ddf200b  Not Available
#
# [1397 rows x 24 columns]
